# %%
import requests as rq

# %%
r=rq.get("http://127.0.0.1:5000?host=icmplus.neurosurg.cam.ac.uk")
r.json()
# Out:
# {'created': '2018-03-11T00:34:34Z',
#  'hrefs': [{'href': 'http://127.0.0.1:5000/?host=icmplus.neurosurg.cam.ac.uk',
#    'rel': 'self'},
#   {'href': 'http://127.0.0.1:5000/datasets?host=icmplus.neurosurg.cam.ac.uk',
#    'rel': 'database'},
#   {'href': 'http://127.0.0.1:5000/groups?host=icmplus.neurosurg.cam.ac.uk',
#    'rel': 'groupbase'},
#   {'href': 'http://127.0.0.1:5000/datatypes?host=icmplus.neurosurg.cam.ac.uk',
#    'rel': 'typebase'},
#   {'href': 'http://127.0.0.1:5000/groups/e1f6a5aa-24c3-11e8-bc5e-4cbb5813b2f6?host=icmplus.neurosurg.cam.ac.uk',
#    'rel': 'root'}],
#  'lastModified': '2018-03-11T00:34:34Z',
#  'root': 'e1f6a5aa-24c3-11e8-bc5e-4cbb5813b2f6'}

# %%
r=rq.get("http://127.0.0.1:5000/groups?host=icmdata.public.icmplus.neurosurg.cam.ac.uk")
r.json()
#below are the uuid's of the diff groups in our hdf file. Some of the groups are annotations,events, summaries, waves etc.
# Out:
# {'groups': ['5cd3702e-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3703c-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37027-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37022-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3702b-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37024-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3702d-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3703a-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37025-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37034-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3703e-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3701f-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37030-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37029-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37032-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37035-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37020-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37039-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37037-24c4-11e8-bc5e-4cbb5813b2f6'],
#  'hrefs': [{'href': 'http://127.0.0.1:5000/groups?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
#    'rel': 'self'},
# ...

# %%
r=rq.get("http://127.0.0.1:5000/datasets?host=icmdata.public.icmplus.neurosurg.cam.ac.uk")
r.json()
#list of uuids of all the dataset in hdf file in all group
# Out:
# {'datasets': ['5cd3702a-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37028-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37023-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37033-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37038-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37031-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3702c-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3703b-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3703f-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3703d-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37021-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd3702f-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37026-24c4-11e8-bc5e-4cbb5813b2f6',
#   '5cd37036-24c4-11e8-bc5e-4cbb5813b2f6'],
#  'hrefs': [{'href': 'http://127.0.0.1:5000/datasets?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
#    'rel': 'self'},
#   {'href': 'http://127.0.0.1:5000/groups/5cd3701e-24c4-11e8-bc5e-4cbb5813b2f6?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
#    'rel': 'root'},
#   {'href': 'http://127.0.0.1:5000/?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
# ...

# %%
r=rq.get("http://127.0.0.1:5000/datasets/5cd3702a-24c4-11e8-bc5e-4cbb5813b2f6/value?host=icmdata.public.icmplus.neurosurg.cam.ac.uk")
r.json()
# Out:
# {'hrefs': [{'href': 'http://127.0.0.1:5000/datasets/5cd3702a-24c4-11e8-bc5e-4cbb5813b2f6/value?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
#    'rel': 'self'},
#   {'href': 'http://127.0.0.1:5000/groups/5cd3701e-24c4-11e8-bc5e-4cbb5813b2f6?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
#    'rel': 'root'},
#   {'href': 'http://127.0.0.1:5000/datasets/5cd3702a-24c4-11e8-bc5e-4cbb5813b2f6?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
#    'rel': 'owner'},
#   {'href': 'http://127.0.0.1:5000/?host=icmdata.public.icmplus.neurosurg.cam.ac.uk',
#    'rel': 'home'}],
#  'value': [[0.9092695599491181,
#    0.7265068519537413,
#    0.29186562376778924,
#    0.6151163940267207,
#    0.7888455000283834,
#    0.9409195303833696,
#    0.003414696815112972,
#    0.058393153241710904,
#    0.03404437640830715,
#    0.6495229291302009,
#    0.531622849460102,
#    0.6746290680054847,
#    0.10511453325472397,
#    0.11074542812568189,
#    0.457089860288616,
#    0.5926453193143287,
# ...
